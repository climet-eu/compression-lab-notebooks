# %% [markdown]
# # OpenIFS 43r3 data
#
# | [![OpenIFS-badge]][OpenIFS-url] |
# |:-:|
#
# [OpenIFS-badge]: https://img.shields.io/badge/OpenIFS-grey?style=for-the-badge&logo=readthedocs&logoColor=white
# [OpenIFS-url]: https://confluence.ecmwf.int/spaces/OIFS/overview

# %% [markdown]
# ## Experiment Details and Available Data Fields
#
# The dataset contains uncompressed IEEE-754 Standard (1985) 64-bit floating-point output from the OpenIFS 43r3 model.
# The simulation was conducted on a reduced Gaussian octahedral grid (Tco1279), corresponding to a horizontal resolution of approximately 9 km.
# The 5-day forecast was run with a time step length of 600 seconds using a HighResMIP based output configuration.
# The total volume of the available dataset is about 258 GB.
#
#
# There is a single NetCDF file for the surface level fields and separate files for each pressure level field. These data are published under a Creative Commons Attribution 4.0 International (CC BY 4.0) license: <https://apps.ecmwf.int/datasets/licences/general/>.
#
# ### Pressure Level Parameters
#
# The following parameters are available as pressure level fields:
# ```python
# ["z", "t", "q", "w", "vo", "d", "u", "v", "r"]
# ```
#
# These parameters are stored at the following pressure levels (in Pa):
# ```python
#
# [100000, 92500, 85000, 70000, 60000, 50000, 40000, 30000, 25000, 20000, 15000, 10000, 7000, 5000, 3000, 2000, 1000, 500, 100]
#
# ```
# The available time steps start at 2009-10-15 18:00:00 UTC, increasing in 6-hour steps to 2009-10-20 12:00:00 UTC.
#
# ### Surface Level Parameters
#
# The following parameters are available as surface level fields:
# ```python
# [
#     "10u", "10v", "2d", "2t", "cp", "e", "es", "ewss", "msl", "nsss", "ro",
#     "rsn", "sd", "sf", "skt", "slhf", "smlt", "sp", "sro", "sshf", "ssr",
#     "ssrc", "ssrd", "stl1", "stl2", "stl3", "stl4", "str", "strc", "strd",
#     "swvl1", "swvl2", "swvl3", "swvl4", "tcc", "tciw", "tclw", "tcwv", "tisr",
#     "tp", "tsn", "tsr", "tsrc", "ttr", "ttrc",
# ]
# ```
#
# Here, the available time steps start at 2009-10-15 15:00:00 UTC, increasing in 3-hour steps to 2009-10-20 12:00:00 UTC.

# %% [markdown]
# ## Using the `load_OpenIFS_data` Function
#
# To load the NetCDF files, you can use the following function:
#
# ```python
# load_OpenIFS_data(leveltype=None, param=None)
# ```
#
# ### Parameters
#
# - **`leveltype`**: Defines the type of data to load. Choose one of the following:
#   - `"pl"`: Pressure level fields.
#   - `"sfc"`: Surface level fields.
# - **`param`**: Specifies the parameter of the pressure level data. Options include: `"q"`, `"r"`, `"t"`, `"u"`, `"v"`, `"vo"`, `"w"`, `"v"` and `"z"`.

# %%
import sys

sys.path.insert(0, "..")

# %%
# URL of S3 bucket
BASE_URL = "https://object-store.os-api.cci1.ecmwf.int/esiwacebucket"

# %% [markdown]
# First, the package `zarr` (modern dataset format that is specifically designed for chunked access) and its dependencies need to be imported for the remote access.

# %% [markdown]
# The `load_OpenIFS_data` function simplifies remote access to NetCDF datasets stored on the S3 bucket. It validates input parameters, constructs the correct URL for the requested data, and loads it efficiently as an xarray dataset using the corresponding `.ref` file.

# %%
import requests
import xarray as xr


def load_OpenIFS_data(leveltype=None, param=None):
    if leveltype not in {"pl", "sfc"}:
        raise ValueError(
            f"Invalid leveltype: '{leveltype}'. Available leveltypes: pl, sfc"
        )

    if leveltype == "pl" and not param:
        raise ValueError(
            f"Param is required for leveltype '{leveltype}'. Available params: q, r, t, u, v, vo, w, z"
        )

    if leveltype == "sfc" and param:
        print(
            "Warning: Specifying 'param' is unnecessary for sfc level and will be ignored."
        )

    if leveltype == "sfc":
        url = f"{BASE_URL}/OpenIFS/HighResMIP_3h_reduced_sfc.nc"
    elif leveltype == "pl":
        if param not in {"q", "r", "t", "u", "v", "vo", "w", "z"}:
            raise ValueError(
                f"Incorrect param: '{param}'. Available: q, r, t, u, v, vo, w, z"
            )

        url = f"{BASE_URL}/OpenIFS/HighResMIP_6h_reduced_pl_{param}.nc"

    ref = requests.get(f"{url}.ref").json()

    print(f"Loading dataset {url}")

    return xr.open_dataset(
        "reference://",
        engine="zarr",
        backend_kwargs={
            "storage_options": {
                "fo": ref,
                "asynchronous": True,
                "remote_options": {"asynchronous": True},
            }
        },
        consolidated=False,
        chunks={},
    )

# %% [markdown]
# ## Example Usage
#
# To load NetCDF file for pressure level parameters, you can use the following example. This will load the **specific humidity (q)** data.

# %%
ds_pl_q = load_OpenIFS_data(leveltype="pl", param="q")
ds_pl_q
# Out:
# Loading dataset https://object-store.os-api.cci1.ecmwf.int/esiwacebucket/OpenIFS/HighResMIP_6h_reduced_pl_q.nc
# <xarray.Dataset> Size: 20GB
# Dimensions:              (cell: 6599680, nvertex: 4, time_counter: 20,
#                           pressure_levels: 19, axis_nbounds: 2)
# Coordinates:
#     lat                  (cell) float32 26MB dask.array<chunksize=(824960,), meta=np.ndarray>
#     lon                  (cell) float32 26MB dask.array<chunksize=(824960,), meta=np.ndarray>
#   * time_counter         (time_counter) datetime64[ns] 160B 2009-10-15T18:00:...
#     time_instant         (time_counter) datetime64[ns] 160B dask.array<chunksize=(1,), meta=np.ndarray>
#   * pressure_levels      (pressure_levels) float32 76B 1e+05 9.25e+04 ... 100.0
# Dimensions without coordinates: cell, nvertex, axis_nbounds
# Data variables:
#     bounds_lat           (cell, nvertex) float32 106MB dask.array<chunksize=(206240, 4), meta=np.ndarray>
#     bounds_lon           (cell, nvertex) float32 106MB dask.array<chunksize=(206240, 4), meta=np.ndarray>
#     q                    (time_counter, pressure_levels, cell) float64 20GB dask.array<chunksize=(1, 1, 412480), meta=np.ndarray>
#     time_counter_bounds  (time_counter, axis_nbounds) datetime64[ns] 320B dask.array<chunksize=(1, 2), meta=np.ndarray>
#     time_instant_bounds  (time_counter, axis_nbounds) datetime64[ns] 320B dask.array<chunksize=(1, 2), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     description:  Created by xios
#     name:         HighResMIP_6h_reduced_pl_q
#     timeStamp:    2024-Apr-05 11:05:21 GMT
#     title:        Created by xios
#     uuid:         25d5f0a2-ceae-47e1-936f-5b1804228ca6

# %% [markdown]
# The `earthkit.plots` package is used for plotting the data.

# %%
import utils

# %% [markdown]
# The data can be visualized as demonstrated below. For example, the specific humidity at **pressure level 1e5Pa** on **2009-10-20 at 12:00:00 UTC** is plotted. `[::10]` applies slicing to the data being plotted (syntax: `[start:stop:step]`) in order to reduce computational load by selecting only every 10th data point.

# %%
utils.quickplot(
    ds_pl_q["q"].sel(
        time_counter="2009-10-20T12:00:00",
        pressure_levels=1e5,
    )[::10],
    x="lon",
    y="lat",
    time="time_counter",
)
# Out:
# 0 date_coordinate
#
# 2 time_coordinate
#     TimeCoordinate[name=time_counter,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#     TimeCoordinate[name=time_instant,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#
# 0 step_coordinate
#
# 0 date_coordinate
#
# 2 time_coordinate
#     TimeCoordinate[name=time_counter,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#     TimeCoordinate[name=time_instant,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#
# 0 step_coordinate
#
# 0 date_coordinate
#
# 2 time_coordinate
#     TimeCoordinate[name=time_counter,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#     TimeCoordinate[name=time_instant,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#
# 0 step_coordinate
#
# 0 date_coordinate
#
# 2 time_coordinate
#     TimeCoordinate[name=time_counter,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#     TimeCoordinate[name=time_instant,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#
# 0 step_coordinate
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 utils.quickplot(
#       2     ds_pl_q["q"].sel(
#       3         time_counter="2009-10-20T12:00:00",
#       4         pressure_levels=1e5,
#
# File ~/compression-lab-notebooks/02-datasets/../utils.py:472, in quickplot(da, chart, method, vrange, error, title, time, cr, **kwargs)
#     460 chart = earthkit.plots.Map() if chart is None else chart
#     462 chart.ax.fill_between(
#     463     [0, 1],
#     464     [1, 1],
#    (...)    469     zorder=-999,
#     470 )
# --> 472 getattr(chart, method)(data, style=style, **kwargs)
#     474 chart.coastlines()
#     475 chart.gridlines()
#
# File ~/compression-lab-notebooks/.venv/lib/python3.14/site-packages/earthkit/plots/components/_pipeline.py:1571, in plot_2D.<locals>.decorator.<locals>.wrapper(self, x, y, z, style, every, auto_style, resample, *args, **kwargs)
#    1568     from earthkit.plots.resample import Chain
#    1570     resample = Chain(resample)
# -> 1571 extract_plottables_2D(
#    1572     subplot=self,
#    1573     method_name=method_name or method.__name__,
#    1574     args=args,
#    1575     x=x,
#    1576     y=y,
#    1577     z=z,
#    1578     style=style,
#    1579     every=every,
#    1580     auto_style=auto_style,
#    1581     extract_domain=extract_domain,
#    1582     resample=resample,
#    1583     **kwargs,
#    1584 )
#    1585 return self if self._chainable else (self.layers[-1].mappable if self.layers else None)
#
# File ~/compression-lab-notebooks/.venv/lib/python3.14/site-packages/earthkit/plots/components/_pipeline.py:602, in extract_plottables_2D(subplot, method_name, args, x, y, z, style, no_style, units, x_units, y_units, z_units, every, extract_domain, auto_style, metadata, resample, grid, use_nn_sampling, **kwargs)
#     599 proxy_color = kwargs.get("colors") or kwargs.get("color")
#     601 # Step 4: Apply style scale factor.
# --> 602 z_values = apply_scale_factor(style, source, z)
#     604 # Step 5: Dispatch to specialized grid handlers (HEALPix, octahedral).
#     605 # Returns a mappable when the handler renders the plot; None otherwise.
#     606 mappable = _handle_specialized_grids(
#     607     subplot,
#     608     source,
#    (...)    614     use_nn_sampling=use_nn_sampling,
#     615 )
#
# File ~/compression-lab-notebooks/.venv/lib/python3.14/site-packages/earthkit/plots/components/_style_utils.py:211, in apply_scale_factor(style, source, z)
#     209 if source._data is None and z is None:
#     210     return None
# --> 211 if source.z is None:
#     212     return None
#     213 return style.apply_scale_factor(source.z.values)
#
# File ~/compression-lab-notebooks/.venv/lib/python3.14/site-packages/earthkit/plots/sources/__init__.py:435, in Source.z(self)
#     432 if self._z_dimension is not None:
#     433     return self._z_dimension
# --> 435 self._extract()
#     437 # For vector fields, compute magnitude lazily
#     438 if self._u_coord_info is not None and self._v_coord_info is not None:
#     439     # Compute magnitude from u and v components
#
# File ~/compression-lab-notebooks/.venv/lib/python3.14/site-packages/earthkit/plots/sources/__init__.py:200, in Source._extract(self)
#     197 self._v_dimension = None
#     199 # Extract coordinates using extractor
# --> 200 extracted = self._extractor.extract_coordinates(
#     201     self._x_spec,
#     202     self._y_spec,
#     203     self._z_spec,
#     204     self._u_spec,
#     205     self._v_spec,
#     206     self._context,
#     207 )
#     209 # Store CoordinateInfo objects
#     210 self._x_coord_info = extracted.x
#
# File ~/compression-lab-notebooks/.venv/lib/python3.14/site-packages/earthkit/plots/sources/extractors/xarray.py:94, in XarrayExtractor.extract_coordinates(self, x, y, z, u, v, context)
#      91 da = self._get_dataarray(z, x, y)
#      93 if context.is_2d:
# ---> 94     coords = self._extract_2d_coordinates(da, x, y, z, u, v, context)
#      95 else:
#      96     coords = self._extract_1d_coordinates(da, x, y, context)
#
# File ~/compression-lab-notebooks/.venv/lib/python3.14/site-packages/earthkit/plots/sources/extractors/xarray.py:411, in XarrayExtractor._extract_2d_coordinates(self, da, x, y, z, u, v, context)
#     408     z_units = z_metadata.get("units")
#     410 if z_values.ndim != 2:
# --> 411     raise ValueError(f"Expected 2D data for 2D plot, got {z_values.ndim}D")
#     413 ny, nx = z_values.shape
#     415 # Step 2: Determine x and y coordinates
#     416 # For 2D data, we expect dimension coordinates or explicit arrays
#
# ValueError: Expected 2D data for 2D plot, got 0D

# %% [markdown]
# The surface level data contains all available parameters and can can be loaded as follows.

# %%
ds_sfc = load_OpenIFS_data(leveltype="sfc")
ds_sfc
# Out:
# Loading dataset https://object-store.os-api.cci1.ecmwf.int/esiwacebucket/OpenIFS/HighResMIP_3h_reduced_sfc.nc
# <xarray.Dataset> Size: 95GB
# Dimensions:              (time_counter: 40, cell: 6599680, nvertex: 4,
#                           axis_nbounds: 2)
# Coordinates:
#   * time_counter         (time_counter) datetime64[ns] 320B 2009-10-15T15:00:...
#     time_instant         (time_counter) datetime64[ns] 320B dask.array<chunksize=(1,), meta=np.ndarray>
#     lat                  (cell) float32 26MB dask.array<chunksize=(824960,), meta=np.ndarray>
#     lon                  (cell) float32 26MB dask.array<chunksize=(824960,), meta=np.ndarray>
# Dimensions without coordinates: cell, nvertex, axis_nbounds
# Data variables: (12/49)
#     10u                  (time_counter, cell) float64 2GB dask.array<chunksize=(1, 412480), meta=np.ndarray>
#     10v                  (time_counter, cell) float64 2GB dask.array<chunksize=(1, 412480), meta=np.ndarray>
#     2d                   (time_counter, cell) float64 2GB dask.array<chunksize=(1, 412480), meta=np.ndarray>
#     2t                   (time_counter, cell) float64 2GB dask.array<chunksize=(1, 412480), meta=np.ndarray>
#     bounds_lat           (cell, nvertex) float32 106MB dask.array<chunksize=(206240, 4), meta=np.ndarray>
#     bounds_lon           (cell, nvertex) float32 106MB dask.array<chunksize=(206240, 4), meta=np.ndarray>
#     ...                   ...
#     tp                   (time_counter, cell) float64 2GB dask.array<chunksize=(1, 412480), meta=np.ndarray>
#     tsn                  (time_counter, cell) float64 2GB dask.array<chunksize=(1, 412480), meta=np.ndarray>
#     tsr                  (time_counter, cell) float64 2GB dask.array<chunksize=(1, 412480), meta=np.ndarray>
#     tsrc                 (time_counter, cell) float64 2GB dask.array<chunksize=(1, 412480), meta=np.ndarray>
#     ttr                  (time_counter, cell) float64 2GB dask.array<chunksize=(1, 412480), meta=np.ndarray>
#     ttrc                 (time_counter, cell) float64 2GB dask.array<chunksize=(1, 412480), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     description:  Created by xios
#     name:         HighResMIP_3h_reduced_sfc
#     timeStamp:    2024-Apr-05 10:55:20 GMT
#     title:        Created by xios
#     uuid:         dbac5691-165e-4465-bd75-e403aa400071

# %% [markdown]
# The data can be visualized as demonstrated below. For example, the 2 metre temperature on **2009-10-20 at 12:00:00 UTC** is plotted.

# %%
utils.quickplot(
    ds_sfc["2t"].sel(
        time_counter="2009-10-20T12:00:00",
    )[::10],
    x="lon",
    y="lat",
    time="time_counter",
)
# Out:
# 0 date_coordinate
#
# 2 time_coordinate
#     TimeCoordinate[name=time_counter,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#     TimeCoordinate[name=time_instant,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#
# 0 step_coordinate
#
# 0 date_coordinate
#
# 2 time_coordinate
#     TimeCoordinate[name=time_counter,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#     TimeCoordinate[name=time_instant,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#
# 0 step_coordinate
#
# 0 date_coordinate
#
# 2 time_coordinate
#     TimeCoordinate[name=time_counter,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#     TimeCoordinate[name=time_instant,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#
# 0 step_coordinate
#
# 0 date_coordinate
#
# 2 time_coordinate
#     TimeCoordinate[name=time_counter,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#     TimeCoordinate[name=time_instant,values=2009-10-20T12:00:00.000000000,shape=()] False True False
#
# 0 step_coordinate
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 utils.quickplot(
#       2     ds_sfc["2t"].sel(
#       3         time_counter="2009-10-20T12:00:00",
#       4     )[::10],
#
# File ~/compression-lab-notebooks/02-datasets/../utils.py:472, in quickplot(da, chart, method, vrange, error, title, time, cr, **kwargs)
#     460 chart = earthkit.plots.Map() if chart is None else chart
#     462 chart.ax.fill_between(
#     463     [0, 1],
#     464     [1, 1],
#    (...)    469     zorder=-999,
#     470 )
# --> 472 getattr(chart, method)(data, style=style, **kwargs)
#     474 chart.coastlines()
#     475 chart.gridlines()
#
# File ~/compression-lab-notebooks/.venv/lib/python3.14/site-packages/earthkit/plots/components/_pipeline.py:1571, in plot_2D.<locals>.decorator.<locals>.wrapper(self, x, y, z, style, every, auto_style, resample, *args, **kwargs)
#    1568     from earthkit.plots.resample import Chain
#    1570     resample = Chain(resample)
# -> 1571 extract_plottables_2D(
#    1572     subplot=self,
#    1573     method_name=method_name or method.__name__,
#    1574     args=args,
#    1575     x=x,
#    1576     y=y,
#    1577     z=z,
#    1578     style=style,
#    1579     every=every,
#    1580     auto_style=auto_style,
#    1581     extract_domain=extract_domain,
#    1582     resample=resample,
#    1583     **kwargs,
#    1584 )
#    1585 return self if self._chainable else (self.layers[-1].mappable if self.layers else None)
#
# File ~/compression-lab-notebooks/.venv/lib/python3.14/site-packages/earthkit/plots/components/_pipeline.py:602, in extract_plottables_2D(subplot, method_name, args, x, y, z, style, no_style, units, x_units, y_units, z_units, every, extract_domain, auto_style, metadata, resample, grid, use_nn_sampling, **kwargs)
#     599 proxy_color = kwargs.get("colors") or kwargs.get("color")
#     601 # Step 4: Apply style scale factor.
# --> 602 z_values = apply_scale_factor(style, source, z)
#     604 # Step 5: Dispatch to specialized grid handlers (HEALPix, octahedral).
#     605 # Returns a mappable when the handler renders the plot; None otherwise.
#     606 mappable = _handle_specialized_grids(
#     607     subplot,
#     608     source,
#    (...)    614     use_nn_sampling=use_nn_sampling,
#     615 )
#
# File ~/compression-lab-notebooks/.venv/lib/python3.14/site-packages/earthkit/plots/components/_style_utils.py:211, in apply_scale_factor(style, source, z)
#     209 if source._data is None and z is None:
#     210     return None
# --> 211 if source.z is None:
#     212     return None
#     213 return style.apply_scale_factor(source.z.values)
#
# File ~/compression-lab-notebooks/.venv/lib/python3.14/site-packages/earthkit/plots/sources/__init__.py:435, in Source.z(self)
#     432 if self._z_dimension is not None:
#     433     return self._z_dimension
# --> 435 self._extract()
#     437 # For vector fields, compute magnitude lazily
#     438 if self._u_coord_info is not None and self._v_coord_info is not None:
#     439     # Compute magnitude from u and v components
#
# File ~/compression-lab-notebooks/.venv/lib/python3.14/site-packages/earthkit/plots/sources/__init__.py:200, in Source._extract(self)
#     197 self._v_dimension = None
#     199 # Extract coordinates using extractor
# --> 200 extracted = self._extractor.extract_coordinates(
#     201     self._x_spec,
#     202     self._y_spec,
#     203     self._z_spec,
#     204     self._u_spec,
#     205     self._v_spec,
#     206     self._context,
#     207 )
#     209 # Store CoordinateInfo objects
#     210 self._x_coord_info = extracted.x
#
# File ~/compression-lab-notebooks/.venv/lib/python3.14/site-packages/earthkit/plots/sources/extractors/xarray.py:94, in XarrayExtractor.extract_coordinates(self, x, y, z, u, v, context)
#      91 da = self._get_dataarray(z, x, y)
#      93 if context.is_2d:
# ---> 94     coords = self._extract_2d_coordinates(da, x, y, z, u, v, context)
#      95 else:
#      96     coords = self._extract_1d_coordinates(da, x, y, context)
#
# File ~/compression-lab-notebooks/.venv/lib/python3.14/site-packages/earthkit/plots/sources/extractors/xarray.py:411, in XarrayExtractor._extract_2d_coordinates(self, da, x, y, z, u, v, context)
#     408     z_units = z_metadata.get("units")
#     410 if z_values.ndim != 2:
# --> 411     raise ValueError(f"Expected 2D data for 2D plot, got {z_values.ndim}D")
#     413 ny, nx = z_values.shape
#     415 # Step 2: Determine x and y coordinates
#     416 # For 2D data, we expect dimension coordinates or explicit arrays
#
# ValueError: Expected 2D data for 2D plot, got 0D
